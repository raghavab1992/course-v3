# %%
# %reload_ext autoreload
# %autoreload 2

from fastai import *
from fastai.vision import *

# %%
path = Path('/mnt/datadrive1/h216520/fastai_v3/data/whale_comp')

# %%
path.ls()
# Out:
# [PosixPath('/mnt/datadrive1/h216520/fastai_v3/data/whale_comp/train.csv'),
#  PosixPath('/mnt/datadrive1/h216520/fastai_v3/data/whale_comp/train.zip'),
#  PosixPath('/mnt/datadrive1/h216520/fastai_v3/data/whale_comp/test'),
#  PosixPath('/mnt/datadrive1/h216520/fastai_v3/data/whale_comp/test.zip'),
#  PosixPath('/mnt/datadrive1/h216520/fastai_v3/data/whale_comp/train')]

# %%
data = ImageDataBunch.from_csv(path, folder='train', csv_labels='train.csv', ds_tfms = get_transforms(), size=128, valid_pct=.01)

# %%
data.show_batch(rows=3)

# %%
x = data.one_batch()

# %%
x[0].shape
# Out:
# torch.Size([64, 3, 128, 128])

# %%
learner = create_cnn(data, models.resnet18, metrics=accuracy)

# %%
learner.lr_find()
# Out:
# epoch  train_loss  valid_loss  accuracy
# 1      42.623089
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learner.recorder.plot()

# %%
learner.fit(1)
# Out:
# epoch  train_loss  valid_loss  accuracy
# Exception ignored in: <bound method _DataLoaderIter.__del__ of <torch.utils.data.dataloader._DataLoaderIter object at 0x7f5db3586da0>>
# Traceback (most recent call last):
#   File "/mnt/datadrive1/anaconda3/envs/fastai_v3/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 717, in __del__
#     self._shutdown_workers()
#   File "/mnt/datadrive1/anaconda3/envs/fastai_v3/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 713, in _shutdown_workers
#     w.join()
#   File "/mnt/datadrive1/anaconda3/envs/fastai_v3/lib/python3.6/multiprocessing/process.py", line 122, in join
#     assert self._parent_pid == os.getpid(), 'can only join a child process'
# AssertionError: can only join a child process
# Exception ignored in: <bound method _DataLoaderIter.__del__ of <torch.utils.data.dataloader._DataLoaderIter object at 0x7f5db3586da0>>
# Traceback (most recent call last):
# ...
